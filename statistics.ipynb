# %% [markdown]
# ## Welcome to Detective Agency

# %%
from src.DigitalTwin import QuickStart

from matplotlib import pyplot as plt
import seaborn as sns

# %%
agency= QuickStart().go()

# %% [markdown]
# Clients

# %%
plt.figure(figsize=(15,5))      
plt.subplot(1,3,1)
sns.histplot([client.age for client in agency.clients])
plt.subplot(1,3,2)
sns.histplot([client.sex for client in agency.clients])
plt.subplot(1,3,3)
sns.histplot([client.problem_type for client in agency.clients])
# Out:
# <Axes: ylabel='Count'>
